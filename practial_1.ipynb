# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyDahitJ/Computer_Vision/blob/main/practial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("/content/drive/MyDrive/Computer_vision/cu_4.jpeg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=540x1170 at 0x7F1795D10D50>

# %%
cv2.imwrite("image.jpeg", img)
# Out:
# True

# %%
path = "/content/drive/MyDrive/Computer_vision/g_img.png"

gray_scale_img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_img)
cv2.imwrite(path, gray_scale_img)
# Out:
# <PIL.Image.Image image mode=L size=540x1170 at 0x7F1797F23410>
# True
